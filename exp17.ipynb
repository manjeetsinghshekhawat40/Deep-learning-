# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')

text = """
Natural Language Processing is a branch of Artificial Intelligence
that helps computers understand human language.
"""

# Tokenization
tokens = word_tokenize(text)

print("Tokens:\n")
print(tokens)

# Stemming
ps = PorterStemmer()

stemmed_words = []

for word in tokens:
    stemmed_words.append(ps.stem(word))

print("\nStemmed Words:\n")
print(stemmed_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokens:
#
# ['Natural', 'Language', 'Processing', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', 'that', 'helps', 'computers', 'understand', 'human', 'language', '.']
#
# Stemmed Words:
#
# ['natur', 'languag', 'process', 'is', 'a', 'branch', 'of', 'artifici', 'intellig', 'that', 'help', 'comput', 'understand', 'human', 'languag', '.']

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import LancasterStemmer

# Sample Text
text = "Students are studying Natural Language Processing using NLTK library."

# Tokenization
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)

print("Tokens:\n")
print(tokens)

# Stemming
stemmer = LancasterStemmer()

stemmed_words = []

for word in tokens:
    stemmed_words.append(stemmer.stem(word))

print("\nStemmed Words:\n")
print(stemmed_words)
# Out:
# Tokens:
#
# ['Students', 'are', 'studying', 'Natural', 'Language', 'Processing', 'using', 'NLTK', 'library']
#
# Stemmed Words:
#
# ['stud', 'ar', 'study', 'nat', 'langu', 'process', 'us', 'nltk', 'libr']
